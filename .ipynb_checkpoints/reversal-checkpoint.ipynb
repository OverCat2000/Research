# %%
import pickle
import psycopg2
import datetime
import time
import numpy as np
import pandas as pd
from scipy.signal import find_peaks
import matplotlib.pyplot as plt
import seaborn as sns
import mplfinance as mpf
import hashlib
import math

# %%
def dbloader(stock, year=2000):
    DATABASE_URL = "postgresql://overcat:overmind@localhost:5432/stocks"
    
    conn = psycopg2.connect(DATABASE_URL)
    cur = conn.cursor()
    
    date_time = datetime.datetime(year, 1, 1, 5, 30)
    limit_stamp = int(time.mktime(date_time.timetuple()))
    
    cur.execute(f"SELECT * FROM {stock} WHERE timestamp > {limit_stamp} ")
    
    rows = cur.fetchall()

    return rows

def to_mat(rows):
    rows = sorted(rows, key=lambda row: row[0])
    window = [row[0: 6] for row in rows]
    window = np.array(window)
    Time = window[:, 0]
    Open = window[:, 1]
    High = window[:, 3]
    Low = window[:, 4]
    Close = window[:, 2]
    Volume = window[:, 5]
    mat = np.vstack((Open, High, Low, Close, Time, Volume))
    return mat

# %%
import json

with open('turnover.json', 'r') as f:
    tickers = json.load(f)

stock_info = pd.read_csv("stock_info.csv")

# %%
def candle(mat, t0, ax):
    data = {
        'Open': mat[0],
        'High': mat[1],
        'Low': mat[2],
        'Close': mat[3]
    }

    # Create DataFrame for first dataset
    df = pd.DataFrame(data)
    # df.index = pd.to_datetime(mat[4], unit='s')
    # df.index = pd.date_range(start="2023-01-01", periods=len(df), freq="D")
    df.index = pd.to_datetime(mat[4], unit='s')
    df["mco"] = None
    df.loc[df.index < t0, "mco"] = "black"
    mco = df["mco"].values
    # mpf.plot(df, type='candle', style='yahoo', ax=ax, marketcolor_overrides=mco)

    mpf.plot(df, type='candle', style='yahoo', marketcolor_overrides=mco, ax=ax)

# %%
tickers[:1]
# Out:
# ['UBC']

# %%
def to_json(matrix):
            mat_list = matrix.tolist()
            mat_dict = {"Open": mat_list[0], "High": mat_list[1], "Low": mat_list[2], "Close": mat_list[3], "Time": mat_list[4], "Volume": mat_list[5]}
            return json.dumps(mat_dict)

# %%
# records = []

for i in tickers:
    record = {}
    rows = dbloader(i)
    mat = to_mat(rows)
    cp = mat[3]
    t = mat[4]
    t = pd.to_datetime(t, unit='s').sort_values()

    prom = np.mean([np.std(i) for i in np.array_split(cp, 10)])
    peaks, _ = find_peaks(cp, prominence=prom)
    valleys, _ = find_peaks(-cp, prominence=prom)
    platto = []


    t_pairs = []
    for k in range(len(valleys)):
        valley = valleys[k]
    
        for j in range(len(peaks)):
            peak = peaks[j]
            if valley < peak:
                t_pairs.append((t[valley], t[peak]))
                break

    alt_pairs = []
    for k in range(len(peaks)):
        peak = peaks[k]
    
        for j in range(len(valleys)):
            valley = valleys[j]
            if valley > peak:
                alt_pairs.append((t[peak], t[valley]))
                break
                
    # record["Stock"] = i
    # record["Company"] = stock_info[stock_info["security"] == f"{i}.N0000"]["company_name"].values[0]
    # record["Count"] = len(t_pairs)
    # records.append(record)
                
    # fig, axes = plt.subplots(int(np.ceil(len(alt_pairs) / 3)), 3, figsize=(14, 20))
    # axes = axes.flatten()

    # for idx, date in enumerate(t_pairs):
        
    #     temp_neutral = t_pairs[idx]
    #     index0_neutral = np.where(t == temp_neutral[0])[0][0]
    #     index1_neutral = np.where(t == temp_neutral[1])[0][0]
    #     dif = index1_neutral - index0_neutral

    #     if  dif > 42:
    #         num1 = math.floor(dif / 3) + index0_neutral
    #         matrix1_neutral = mat[:, num1-14:num1]
    #         matrix2_neutral = mat[:, num1:num1+28]
    #         mm_neutral = mat[:, num1-14:num1+28]
    #         # print(matrix1_neutral.shape, matrix2_neutral.shape, mm_neutral.shape)
            
    #         # fig, axes = plt.subplots(1, 1)
    #         # candle(mm_neutral, axes, t[num1])
    #         # axes.set_xticks([])  # Remove x-axis ticks
    #         # axes.set_yticks([])  # Remove y-axis ticks
    #         # axes.set_ylabel("")
    #         # plt.tight_layout()

    #         try:
    #             insert_db(matrix1_neutral, matrix2_neutral, i, t[num1], 0)
    #         except psycopg2.Error as e:
    #             print(f"Error occurred: {e}")

    u_pairs = t_pairs + alt_pairs

    for idx, date in enumerate(u_pairs):
        temp_neutral = u_pairs[idx]
        index0_neutral = np.where(t == temp_neutral[0])[0][0]
        index1_neutral = np.where(t == temp_neutral[1])[0][0]
        dif = index1_neutral - index0_neutral
    
        if  dif > 32:
            # num1 = math.floor(dif / 3) + index0_neutral
            num1 = math.floor(dif / 2) + index0_neutral
            platto.append(num1)
            matrix1_neutral = mat[:, num1-8:num1+8]
            matrix2_neutral = mat[:, num1+8:index1_neutral]
            
            try:
                insert_db(matrix1_neutral, matrix2_neutral, i, t[num1], 0)
            except psycopg2.Error as e:
                print(f"Error occurred: {e}")
            
        else:
            print(index0_alt)
            pass

    for idx, date in enumerate(t_pairs):
        # print("##############################")
        
        temp = t_pairs[idx]
        # t2 = (t >= temp[0]) & (t <= temp[1])

        index0 = np.where(t == temp[0])[0][0]
        index1 = np.where(t == temp[1])[0][0]

        if index0 >= 15:
            matrix1 = mat[:, index0-15:index0+1]
            matrix2 = mat[:, index0+1:index1+1]
            mm = mat[:, index0-15:index1+1]
            
            # candle(mm, axes[idx], temp[0])
            # axes[idx].set_xticks([])  # Remove x-axis ticks
            # axes[idx].set_yticks([])  # Remove y-axis ticks
            # axes[idx].set_ylabel("")
            # plt.tight_layout()

            try:
                insert_db(matrix1, matrix2, i, temp[0], 1)
            except psycopg2.Error as e:
                print(f"Error occurred: {e}")
        else:
            print(index0)
            pass
        
    for idx, date in enumerate(alt_pairs):
        temp_alt = alt_pairs[idx]
        # t2 = (t >= temp[0]) & (t <= temp[1])

        index0_alt = np.where(t == temp_alt[0])[0][0]
        index1_alt = np.where(t == temp_alt[1])[0][0]

        if index0_alt >= 15:
            matrix1_alt = mat[:, index0_alt-15:index0_alt+1]
            matrix2_alt = mat[:, index0_alt+1:index1_alt+1]
            mm_alt = mat[:, index0_alt-15:index1_alt+1]
            
            # candle(mm_alt, axes[idx], temp_alt[0])
            # axes[idx].set_xticks([])  # Remove x-axis ticks
            # axes[idx].set_yticks([])  # Remove y-axis ticks
            # axes[idx].set_ylabel("")
            # plt.tight_layout()

            try:
                insert_db(matrix1_alt, matrix2_alt, i, temp_alt[0], 2)
            except psycopg2.Error as e:
                print(f"Error occurred: {e}")
            
        else:
            print(index0_alt)
            pass

     
        

        # candle(mm, axes[idx], temp[0])
        # axes[idx].plot(t[t2], cp[t2])
        # axes[idx].plot(t[t1], cp[t1], c="r")

        # plt.savefig("/mnt/c/Users/malis/Desktop/Linux/trend_reversal.png", dpi=300, bbox_inches='tight')

        ############
        # dif = temp[1] - temp[0]
        # dif = datetime.timedelta(days=14)
        ############
        
        # origin = temp[0] - dif
        # t1 = (t >= origin) & (t < temp[0])
        # m1 = mat[:, t1]
        # m2 = mat[:, t2]

        # tt = (t >= origin) & (t <= temp[1])
        # mm = mat[:, tt]
        
        # matrix1 = mm[:, mm[4] < temp[0].timestamp()]
        # matrix2 = mm[:, mm[4] > temp[0].timestamp()]

    #########
    # plt.figure(figsize=(10, len(t_pairs)))
    # plt.figure(figsize=(10, 7))
    # plt.plot(cp, alpha=0.5)
    # plt.plot(peaks, cp[peaks], "x", )
    # plt.plot(valleys, cp[valleys], "o")
    # plt.plot(platto, cp[platto], "_")
    # plt.title(f"{i} peaks and valleys")
    # plt.xticks([])
    # plt.yticks([])
    # plt.savefig("/mnt/c/Users/malis/Desktop/Linux/tjl_p_v.png", dpi=300, bbox_inches='tight')
# Out:
# 3798
# 3798
# 3798
# data inserted successfully
# 3798
# 3798
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3798
# 3798
# 3798
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3798
# 3798
# data inserted successfully
# data inserted successfully
# 3798
# 3798
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3798
# 3798
# data inserted successfully
# 3798
# data inserted successfully
# data inserted successfully
# 3798
# 3798
# 3798
# 3798
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2938
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2938
# 2938
# 2938
# 2938
# data inserted successfully
# 2938
# 2938
# 2938
# 2938
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2938
# 2938
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2938
# data inserted successfully
# data inserted successfully
# 2938
# 2938
# 2938
# data inserted successfully
# 2938
# 2938
# 2938
# 2938
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3048
# data inserted successfully
# 3048
# 3048
# 3048
# 3048
# 3048
# 3048
# 3048
# 3048
# 3048
# 3048
# 3048
# 3048
# 3048
# data inserted successfully
# 3048
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3048
# 3048
# 3048
# 3048
# 3048
# 3048
# 3048
# 3048
# 3048
# 3048
# 3048
# 3048
# 3048
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 1805
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 1805
# 1805
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2936
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2936
# 2936
# 2936
# data inserted successfully
# 2936
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2936
# 2936
# 2936
# 2936
# data inserted successfully
# data inserted successfully
# 2936
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3737
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3737
# 3737
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3737
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3737
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3737
# 3737
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3437
# 3437
# 3437
# 3437
# 3437
# 3437
# 3437
# 3437
# data inserted successfully
# 3437
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3437
# 3437
# 3437
# 3437
# data inserted successfully
# 3437
# 3437
# 3437
# data inserted successfully
# 3437
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2825
# data inserted successfully
# 2825
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2825
# 2825
# 2825
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2539
# 2539
# 2539
# data inserted successfully
# 2539
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2539
# 2539
# 2539
# data inserted successfully
# 2539
# data inserted successfully
# 2539
# 2539
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2539
# 2539
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2539
# 2539
# 2539
# 2539
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2670
# data inserted successfully
# data inserted successfully
# 2670
# 2670
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2670
# 2670
# 2670
# data inserted successfully
# 2670
# 2670
# 2670
# 2670
# 2670
# 2670
# 2670
# 2670
# 2670
# 2670
# data inserted successfully
# 2670
# 2670
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2670
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2670
# 2670
# 2670
# data inserted successfully
# 2670
# 2670
# 2670
# 2670
# 2670
# 2670
# 2670
# 2670
# 2670
# 2670
# 2670
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2670
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3798
# 3798
# 3798
# 3798
# 3798
# data inserted successfully
# data inserted successfully
# 3798
# data inserted successfully
# data inserted successfully
# 3798
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3798
# 3798
# 3798
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3798
# 3798
# 3798
# 3798
# 3798
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3798
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3798
# data inserted successfully
# 3798
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3798
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3683
# 3683
# 3683
# 3683
# 3683
# 3683
# 3683
# 3683
# data inserted successfully
# 3683
# 3683
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3683
# 3683
# data inserted successfully
# data inserted successfully
# 3683
# 3683
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3683
# 3683
# 3683
# 3683
# 3683
# 3683
# 3683
# 3683
# 3683
# 3683
# data inserted successfully
# 3683
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3693
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2940
# data inserted successfully
# data inserted successfully
# 2940
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2940
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2940
# 2940
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2358
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2358
# 2358
# data inserted successfully
# 2358
# 2358
# 2358
# 2358
# data inserted successfully
# data inserted successfully
# 2358
# 2358
# 2358
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2358
# 2358
# 2358
# data inserted successfully
# data inserted successfully
# 2358
# 2358
# data inserted successfully
# data inserted successfully
# 2358
# 2358
# 2358
# 2358
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 9
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 1694
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 1694
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 1694
# data inserted successfully
# 1694
# 1694
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3723
# 3723
# 3723
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3723
# 3723
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3723
# data inserted successfully
# 3723
# data inserted successfully
# 3723
# 3723
# 3723
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3723
# 3723
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3723
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3722
# data inserted successfully
# data inserted successfully
# 3722
# 3722
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3722
# 3722
# 3722
# 3722
# 3722
# 3722
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3722
# data inserted successfully
# 3722
# data inserted successfully
# data inserted successfully
# 3722
# 3722
# 3722
# data inserted successfully
# 3722
# 3722
# 3722
# 3722
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3423
# 3423
# data inserted successfully
# 3423
# 3423
# 3423
# 3423
# 3423
# 3423
# 3423
# 3423
# 3423
# 3423
# 3423
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3423
# 3423
# 3423
# 3423
# 3423
# 3423
# 3423
# 3423
# 3423
# 3423
# 3423
# 3423
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3750
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3750
# 3750
# 3750
# 3750
# 3750
# 3750
# 3750
# 3750
# 3750
# 3750
# 3750
# 3750
# 3750
# 3750
# 3750
# data inserted successfully
# data inserted successfully
# 3750
# 3750
# 3750
# data inserted successfully
# 3750
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3750
# data inserted successfully
# 3750
# 3750
# 3750
# data inserted successfully
# 3750
# 3750
# 3750
# 3750
# 3750
# data inserted successfully
# 3750
# data inserted successfully
# 3750
# 3750
# 3750
# 3750
# data inserted successfully
# data inserted successfully
# 3750
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2052
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2052
# 2052
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3557
# 3557
# 3557
# 3557
# 3557
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3557
# 3557
# 3557
# 3557
# 3557
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3635
# 3635
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3635
# 3635
# 3635
# 3635
# data inserted successfully
# 3635
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3635
# 3635
# 3635
# 3635
# 3635
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2961
# data inserted successfully
# data inserted successfully
# 2961
# 2961
# 2961
# 2961
# 2961
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2961
# 2961
# 2961
# 2961
# 2961
# 2961
# 2961
# data inserted successfully
# 2961
# 2961
# 2961
# 2961
# data inserted successfully
# data inserted successfully
# 2961
# 2961
# 2961
# 2961
# 2961
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3098
# data inserted successfully
# data inserted successfully
# 3098
# 3098
# 3098
# 3098
# 3098
# 3098
# 3098
# 3098
# 3098
# 3098
# 3098
# 3098
# 3098
# 3098
# 3098
# data inserted successfully
# data inserted successfully
# 3098
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3098
# 3098
# 3098
# 3098
# 3098
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3098
# data inserted successfully
# 3098
# 3098
# 3098
# 3098
# data inserted successfully
# 3098
# 3098
# data inserted successfully
# 3098
# 3098
# 3098
# 3098
# 3098
# data inserted successfully
# 3098
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3098
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3098
# data inserted successfully
# 3098
# 3098
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3563
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3563
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3563
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3728
# data inserted successfully
# 3728
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3728
# 3728
# 3728
# 3728
# data inserted successfully
# 3728
# 3728
# data inserted successfully
# 3728
# 3728
# 3728
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3728
# 3728
# 3728
# 3728
# 3728
# 3728
# 3728
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3046
# data inserted successfully
# data inserted successfully
# 3046
# data inserted successfully
# data inserted successfully
# 3046
# data inserted successfully
# 3046
# 3046
# 3046
# 3046
# 3046
# 3046
# 3046
# 3046
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3046
# data inserted successfully
# data inserted successfully
# 3046
# 3046
# 3046
# 3046
# 3046
# 3046
# 3046
# 3046
# 3046
# 3046
# 3046
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3024
# 3024
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3024
# 3024
# 3024
# 3024
# 3024
# 3024
# 3024
# 3024
# 3024
# 3024
# 3024
# 3024
# 3024
# 3024
# 3024
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3024
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3024
# 3024
# 3024
# 3024
# 3024
# 3024
# 3024
# 3024
# 3024
# 3024
# 3024
# 3024
# 3024
# 3024
# 3024
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2
# 11
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 5
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3011
# 3011
# 3011
# 3011
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3011
# data inserted successfully
# data inserted successfully
# 3011
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3011
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3117
# 3117
# 3117
# 3117
# 3117
# 3117
# 3117
# 3117
# 3117
# 3117
# 3117
# 3117
# 3117
# 3117
# 3117
# data inserted successfully
# data inserted successfully
# 3117
# 3117
# 3117
# 3117
# 3117
# 3117
# data inserted successfully
# 3117
# 3117
# 3117
# 3117
# 3117
# 3117
# 3117
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 7
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 2
# 8
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 511
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# data inserted successfully
# data inserted successfully
# 511
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# 511
# data inserted successfully
# 511
# 511
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 511
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3105
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3105
# 3105
# 3105
# 3105
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3105
# 3105
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3105
# 3105
# 3105
# 3105
# 3105
# 3105
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3085
# 3085
# 3085
# 3085
# 3085
# 3085
# 3085
# 3085
# 3085
# 3085
# 3085
# 3085
# 3085
# 3085
# 3085
# 3085
# 3085
# data inserted successfully
# data inserted successfully
# 3085
# 3085
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3085
# data inserted successfully
# data inserted successfully
# 3085
# 3085
# 3085
# 3085
# 3085
# 3085
# 3085
# 3085
# 3085
# 3085
# 3085
# 3085
# data inserted successfully
# 3085
# data inserted successfully
# 3085
# 3085
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# 3085
# 3085
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully
# data inserted successfully

# %%
# fig, axes = plt.subplots(int(np.ceil(len(alt_pairs) / 3)), 3, figsize=(14, 20))
# axes = axes.flatten()

platto = []
u_pairs = t_pairs + alt_pairs

for idx, date in enumerate(u_pairs):
    temp_neutral = u_pairs[idx]
    index0_neutral = np.where(t == temp_neutral[0])[0][0]
    index1_neutral = np.where(t == temp_neutral[1])[0][0]
    dif = index1_neutral - index0_neutral

    if  dif > 32:
        # num1 = math.floor(dif / 3) + index0_neutral
        num1 = math.floor(dif / 2) + index0_neutral
        platto.append(num1)
        matrix1_neutral = mat[:, num1-8:num1+8]
        matrix2_neutral = mat[:, num1+8:index1_neutral]
        
        # fig, axes = plt.subplots(1, 1)
        # candle(mm_neutral, t[num1], axes)
        # axes.set_xticks([])  # Remove x-axis ticks
        # axes.set_yticks([])  # Remove y-axis ticks
        # axes.set_ylabel("")
        # plt.tight_layout()

# %%
platto
# Out:
# [236,
#  314,
#  447,
#  449,
#  661,
#  756,
#  849,
#  1465,
#  1670,
#  1939,
#  2240,
#  2462,
#  2671,
#  2688,
#  2861,
#  53,
#  145,
#  378,
#  530,
#  581,
#  1051,
#  1329,
#  1563,
#  1566,
#  1769,
#  2098,
#  2345,
#  2595,
#  2748,
#  3061]

# %%
# matrix1 = mm[:, mm[4] < temp[0].timestamp()]
# matrix2 = mm[:, mm[4] > temp[0].timestamp()]
# matrix1.shape, matrix2.shape

# def to_json(matrix):
#     mat_list = matrix.tolist()
#     mat_dict = {"Open": mat_list[0], "High": mat_list[1], "Low": mat_list[2], "Close": mat_list[3], "Time": mat_list[4]}
#     return json.dumps(mat_dict)

# %%
DATABASE_URL = "postgresql://overcat:overmind@localhost:5432/stocks"
conn = psycopg2.connect(DATABASE_URL)

query = """
DO $$
BEGIN
    -- Create schema if it doesn't exist
    IF NOT EXISTS (SELECT 1 FROM information_schema.schemata WHERE schema_name = 'data') THEN
        EXECUTE 'CREATE SCHEMA data';
    END IF;

    -- Create table if it doesn't exist
    IF NOT EXISTS (
        SELECT 1 FROM information_schema.tables 
        WHERE table_schema = 'data' AND table_name = 'reversals'
    ) THEN
        EXECUTE '
        CREATE TABLE data.reversals (
            id TEXT PRIMARY KEY, 
            matrix1 JSONB NOT NULL,
            matrix2 JSONB NOT NULL,
            stock TEXT NOT NULL,
            point TIMESTAMP NOT NULL,
            trend INTEGER
        )';
    END IF;
END $$;
"""
try:
    with conn.cursor() as cur:
        cur.execute(query)
        conn.commit()
        print("schema and table created successfully")
finally:
    conn.close()
# Out:
# schema and table created successfully

# %%
def generate_unique_number(stock_name, stock_date):
    # Combine stock name and date into a string
    combined_string = f"{stock_name}_{stock_date.strftime('%Y%m%d')}"
    
    # Hash the combined string using SHA-256
    hash_object = hashlib.sha256(combined_string.encode())
    hex_dig = hash_object.hexdigest()
    
    # Convert the hex digest into a number (you can also take a substring of the hash for a shorter number)
    unique_number = int(hex_dig, 16)  # Convert hex to an integer
    
    # Optionally, limit the size of the number (e.g., modulo a large number to prevent overflow)
    unique_number = unique_number % (10**18)  # Limiting it to an 18-digit number
    
    return unique_number

# %%
def insert_db(matrix1, matrix2, stock, point, trend):
    DATABASE_URL = "postgresql://overcat:overmind@localhost:5432/stocks"
    conn = psycopg2.connect(DATABASE_URL)
    
    query = """
    INSERT INTO data.reversals (id, matrix1, matrix2, stock, point, trend)
    VALUES (%s, %s, %s, %s, %s, %s)
    """
    try:
        with conn.cursor() as cur:
            cur.execute(query, [generate_unique_number(stock, point), to_json(matrix1), to_json(matrix2), stock, point.strftime('%Y-%m-%d'), trend])
            conn.commit()
            print("data inserted successfully")
    finally:
        conn.close()

# %%
def pgDataLoader():
    DATABASE_URL = "postgresql://overcat:overmind@localhost:5432/stocks"
    conn = psycopg2.connect(DATABASE_URL)
    
    query = """
    SELECT * from data.reversals;
    """
    
    dataset = []
    
    try:
        conn = psycopg2.connect(DATABASE_URL)
        with conn.cursor() as cur:
            cur.execute(query)
            results = cur.fetchall()  # Fetch all rows from the query result
            
            for row in results:
                matrix1 = np.array([
                    row[1]["Open"],
                    row[1]["High"],
                    row[1]["Low"],
                    row[1]["Close"],
                    row[1]["Time"],
                    row[1]["Volume"]
                ])
    
                matrix2 = np.array([
                    row[2]["Open"],
                    row[2]["High"],
                    row[2]["Low"],
                    row[2]["Close"],
                    row[2]["Time"],
                    row[2]["Volume"]
                ])
    
                # print(row[3], row[4])
                # fig, axes = plt.subplots(1, 1)
                # candle(np.concatenate((matrix1, matrix2), axis=1), ax=axes, t0=row[4])
    
                matrix1 = np.moveaxis(matrix1, 1, 0)
                matrix2 = np.moveaxis(matrix2, 1, 0)
    
                # fig, axes = plt.subplots(1, 1)
                # candle(np.moveaxis(np.concatenate((matrix1, matrix2)), 1, 0), ax=axes, t0=temp[0])
                dataset.append((matrix1, matrix2, row[4], row[5]))
    finally:
        conn.close()
        
    return dataset

# %%
dataset = pgDataLoader()

# %%
len(dataset)
# Out:
# 1355

# %%
dataset[0]
# Out:
# (array([[5.7000000e+00, 5.8000000e+00, 5.5000000e+00, 5.6000000e+00,
#          1.7126208e+09, 4.0264000e+06],
#         [5.6000000e+00, 5.9000000e+00, 5.5000000e+00, 5.8000000e+00,
#          1.7127072e+09, 4.9521500e+06],
#         [5.9000000e+00, 6.2000000e+00, 5.7000000e+00, 6.1000000e+00,
#          1.7131392e+09, 2.7016462e+07],
#         [6.1000000e+00, 6.1000000e+00, 5.8000000e+00, 5.9000000e+00,
#          1.7132256e+09, 1.0973956e+07],
#         [5.9000000e+00, 6.1000000e+00, 5.8000000e+00, 6.0000000e+00,
#          1.7133120e+09, 5.5478690e+06],
#         [6.1000000e+00, 6.2000000e+00, 5.9000000e+00, 6.1000000e+00,
#          1.7133984e+09, 8.0366410e+06],
#         [5.9000000e+00, 6.5000000e+00, 5.9000000e+00, 6.4000000e+00,
#          1.7134848e+09, 2.7047967e+07],
#         [6.4000000e+00, 7.2000000e+00, 6.4000000e+00, 7.0000000e+00,
#          1.7137440e+09, 3.3908638e+07],
#         [7.1000000e+00, 7.5000000e+00, 6.9000000e+00, 7.4000000e+00,
#          1.7139168e+09, 4.4040060e+07],
#         [7.4000000e+00, 7.4000000e+00, 7.0000000e+00, 7.2000000e+00,
#          1.7140032e+09, 2.5197209e+07],
#         [7.2000000e+00, 7.5000000e+00, 7.1000000e+00, 7.2000000e+00,
#          1.7140896e+09, 2.2399080e+07],
#         [7.2000000e+00, 7.3000000e+00, 6.9000000e+00, 7.0000000e+00,
#          1.7143488e+09, 4.7946590e+06],
#         [7.0000000e+00, 7.1000000e+00, 6.8000000e+00, 7.0000000e+00,
#          1.7144352e+09, 5.8513390e+06],
#         [7.0000000e+00, 7.2000000e+00, 7.0000000e+00, 7.0000000e+00,
#          1.7146080e+09, 3.1433640e+06],
#         [7.0000000e+00, 7.1000000e+00, 6.9000000e+00, 7.0000000e+00,
#          1.7146944e+09, 2.1995410e+06],
#         [7.1000000e+00, 7.5000000e+00, 7.0000000e+00, 7.4000000e+00,
#          1.7149536e+09, 1.7337010e+07]]),
#  array([[7.4000000e+00, 7.5000000e+00, 7.3000000e+00, 7.4000000e+00,
#          1.7150400e+09, 5.3054930e+06],
#         [7.4000000e+00, 7.4000000e+00, 7.0000000e+00, 7.1000000e+00,
#          1.7151264e+09, 7.4817730e+06],
#         [7.1000000e+00, 7.2000000e+00, 6.9000000e+00, 7.1000000e+00,
#          1.7152128e+09, 6.9057440e+06],
#         [7.2000000e+00, 7.3000000e+00, 7.1000000e+00, 7.1000000e+00,
#          1.7152992e+09, 5.8471690e+06],
#         [7.2000000e+00, 7.2000000e+00, 6.9000000e+00, 7.0000000e+00,
#          1.7155584e+09, 5.1358250e+06],
#         [7.0000000e+00, 7.1000000e+00, 6.6000000e+00, 6.8000000e+00,
#          1.7156448e+09, 7.6632840e+06],
#         [6.8000000e+00, 7.0000000e+00, 6.5000000e+00, 6.5000000e+00,
#          1.7157312e+09, 9.0115870e+06],
#         [6.6000000e+00, 6.8000000e+00, 6.5000000e+00, 6.6000000e+00,
#          1.7158176e+09, 3.0498070e+06],
#         [6.6000000e+00, 6.7000000e+00, 6.5000000e+00, 6.7000000e+00,
#          1.7159040e+09, 7.7951900e+05],
#         [6.7000000e+00, 6.7000000e+00, 6.3000000e+00, 6.4000000e+00,
#          1.7161632e+09, 3.9807420e+06],
#         [6.4000000e+00, 6.5000000e+00, 6.1000000e+00, 6.4000000e+00,
#          1.7162496e+09, 7.6860820e+06],
#         [6.5000000e+00, 6.8000000e+00, 6.5000000e+00, 6.7000000e+00,
#          1.7163360e+09, 5.8051390e+06],
#         [6.7000000e+00, 6.8000000e+00, 6.6000000e+00, 6.6000000e+00,
#          1.7167680e+09, 1.4280130e+06],
#         [6.6000000e+00, 6.7000000e+00, 6.4000000e+00, 6.5000000e+00,
#          1.7168544e+09, 2.3897600e+06],
#         [6.6000000e+00, 6.6000000e+00, 6.4000000e+00, 6.4000000e+00,
#          1.7169408e+09, 1.0610180e+06],
#         [6.5000000e+00, 6.6000000e+00, 6.3000000e+00, 6.5000000e+00,
#          1.7170272e+09, 1.8819060e+06],
#         [6.5000000e+00, 6.5000000e+00, 6.3000000e+00, 6.4000000e+00,
#          1.7171136e+09, 6.4154250e+06],
#         [6.5000000e+00, 6.5000000e+00, 6.2000000e+00, 6.3000000e+00,
#          1.7173728e+09, 1.5178490e+06],
#         [6.4000000e+00, 6.6000000e+00, 6.3000000e+00, 6.5000000e+00,
#          1.7174592e+09, 3.6059030e+06],
#         [6.6000000e+00, 6.6000000e+00, 6.4000000e+00, 6.5000000e+00,
#          1.7175456e+09, 2.0342310e+06],
#         [6.6000000e+00, 6.7000000e+00, 6.5000000e+00, 6.6000000e+00,
#          1.7176320e+09, 2.8790660e+06],
#         [6.7000000e+00, 6.7000000e+00, 6.5000000e+00, 6.6000000e+00,
#          1.7177184e+09, 9.2039600e+05],
#         [6.6000000e+00, 6.7000000e+00, 6.5000000e+00, 6.6000000e+00,
#          1.7179776e+09, 2.9020730e+06],
#         [6.6000000e+00, 6.8000000e+00, 6.5000000e+00, 6.6000000e+00,
#          1.7180640e+09, 7.0355690e+06],
#         [6.6000000e+00, 6.7000000e+00, 6.5000000e+00, 6.6000000e+00,
#          1.7181504e+09, 2.5458550e+06],
#         [6.6000000e+00, 6.7000000e+00, 6.5000000e+00, 6.5000000e+00,
#          1.7182368e+09, 7.4271900e+05],
#         [6.6000000e+00, 6.6000000e+00, 6.3000000e+00, 6.3000000e+00,
#          1.7183232e+09, 1.3431560e+06],
#         [6.4000000e+00, 6.5000000e+00, 6.3000000e+00, 6.4000000e+00,
#          1.7186688e+09, 8.4749700e+05],
#         [6.5000000e+00, 6.5000000e+00, 6.3000000e+00, 6.4000000e+00,
#          1.7187552e+09, 1.5505220e+06],
#         [6.4000000e+00, 6.5000000e+00, 6.3000000e+00, 6.3000000e+00,
#          1.7188416e+09, 4.9049100e+05],
#         [6.3000000e+00, 6.5000000e+00, 6.2000000e+00, 6.3000000e+00,
#          1.7191872e+09, 1.6855060e+06],
#         [6.4000000e+00, 6.4000000e+00, 6.2000000e+00, 6.2000000e+00,
#          1.7192736e+09, 1.1587590e+06],
#         [6.3000000e+00, 6.3000000e+00, 6.1000000e+00, 6.2000000e+00,
#          1.7193600e+09, 5.4041600e+05],
#         [6.2000000e+00, 6.3000000e+00, 6.0000000e+00, 6.2000000e+00,
#          1.7194464e+09, 1.4323550e+06],
#         [6.1000000e+00, 6.3000000e+00, 6.1000000e+00, 6.1000000e+00,
#          1.7195328e+09, 8.0577200e+05],
#         [6.1000000e+00, 6.2000000e+00, 6.0000000e+00, 6.1000000e+00,
#          1.7197920e+09, 1.2224710e+06],
#         [6.1000000e+00, 6.2000000e+00, 6.0000000e+00, 6.0000000e+00,
#          1.7198784e+09, 3.7301100e+05],
#         [6.0000000e+00, 6.2000000e+00, 5.9000000e+00, 5.9000000e+00,
#          1.7199648e+09, 1.1942520e+06],
#         [6.0000000e+00, 6.1000000e+00, 5.8000000e+00, 6.0000000e+00,
#          1.7200512e+09, 2.4455080e+06],
#         [6.1000000e+00, 6.1000000e+00, 5.9000000e+00, 6.0000000e+00,
#          1.7201376e+09, 6.5713000e+05],
#         [6.0000000e+00, 6.1000000e+00, 5.7000000e+00, 5.7000000e+00,
#          1.7203968e+09, 4.2890840e+06],
#         [5.8000000e+00, 5.9000000e+00, 5.6000000e+00, 5.6000000e+00,
#          1.7204832e+09, 1.9586940e+06],
#         [5.7000000e+00, 5.9000000e+00, 5.7000000e+00, 5.8000000e+00,
#          1.7205696e+09, 2.0086060e+06],
#         [5.9000000e+00, 5.9000000e+00, 5.7000000e+00, 5.8000000e+00,
#          1.7206560e+09, 1.9762360e+06],
#         [5.9000000e+00, 6.1000000e+00, 5.8000000e+00, 6.0000000e+00,
#          1.7207424e+09, 2.9388560e+06],
#         [6.1000000e+00, 6.2000000e+00, 6.0000000e+00, 6.2000000e+00,
#          1.7210016e+09, 3.7828730e+06],
#         [6.2000000e+00, 6.4000000e+00, 6.1000000e+00, 6.2000000e+00,
#          1.7210880e+09, 3.6130130e+06],
#         [6.1000000e+00, 6.3000000e+00, 6.0000000e+00, 6.1000000e+00,
#          1.7211744e+09, 2.6620610e+06],
#         [6.2000000e+00, 6.2000000e+00, 6.0000000e+00, 6.1000000e+00,
#          1.7212608e+09, 1.5803510e+06],
#         [6.1000000e+00, 6.2000000e+00, 5.9000000e+00, 6.0000000e+00,
#          1.7213472e+09, 1.2662300e+06],
#         [5.9000000e+00, 6.0000000e+00, 5.8000000e+00, 6.0000000e+00,
#          1.7216064e+09, 2.5505470e+06],
#         [6.0000000e+00, 6.2000000e+00, 5.9000000e+00, 6.1000000e+00,
#          1.7216928e+09, 2.1596330e+06],
#         [6.0000000e+00, 6.2000000e+00, 6.0000000e+00, 6.1000000e+00,
#          1.7217792e+09, 1.6065010e+06],
#         [6.1000000e+00, 6.2000000e+00, 5.9000000e+00, 6.0000000e+00,
#          1.7218656e+09, 3.6463000e+05],
#         [6.1000000e+00, 6.1000000e+00, 5.9000000e+00, 6.0000000e+00,
#          1.7219520e+09, 8.7676400e+05],
#         [6.0000000e+00, 6.0000000e+00, 5.9000000e+00, 5.9000000e+00,
#          1.7222112e+09, 1.5454500e+05],
#         [6.0000000e+00, 6.0000000e+00, 5.7000000e+00, 5.7000000e+00,
#          1.7222976e+09, 3.7704950e+06],
#         [5.8000000e+00, 5.9000000e+00, 5.6000000e+00, 5.6000000e+00,
#          1.7223840e+09, 2.4690570e+06],
#         [5.7000000e+00, 5.9000000e+00, 5.6000000e+00, 5.7000000e+00,
#          1.7224704e+09, 1.2026060e+06],
#         [5.6000000e+00, 5.8000000e+00, 5.6000000e+00, 5.7000000e+00,
#          1.7225568e+09, 5.7909500e+05],
#         [5.6000000e+00, 5.7000000e+00, 5.4000000e+00, 5.5000000e+00,
#          1.7228160e+09, 3.2201850e+06],
#         [5.5000000e+00, 5.6000000e+00, 5.4000000e+00, 5.4000000e+00,
#          1.7229024e+09, 7.4569400e+05],
#         [5.5000000e+00, 5.5000000e+00, 5.4000000e+00, 5.5000000e+00,
#          1.7229888e+09, 1.4788500e+05],
#         [5.5000000e+00, 5.6000000e+00, 5.4000000e+00, 5.5000000e+00,
#          1.7230752e+09, 1.2545890e+06],
#         [5.5000000e+00, 5.6000000e+00, 5.5000000e+00, 5.5000000e+00,
#          1.7231616e+09, 1.1400200e+05],
#         [5.5000000e+00, 5.6000000e+00, 5.5000000e+00, 5.5000000e+00,
#          1.7234208e+09, 3.9238300e+05],
#         [5.5000000e+00, 5.7000000e+00, 5.4000000e+00, 5.6000000e+00,
#          1.7235072e+09, 1.9836500e+06],
#         [5.7000000e+00, 5.8000000e+00, 5.6000000e+00, 5.7000000e+00,
#          1.7235936e+09, 1.4260180e+06],
#         [5.7000000e+00, 5.9000000e+00, 5.7000000e+00, 5.8000000e+00,
#          1.7236800e+09, 1.5987580e+06],
#         [5.8000000e+00, 5.8000000e+00, 5.6000000e+00, 5.8000000e+00,
#          1.7237664e+09, 2.2887800e+05],
#         [5.7000000e+00, 5.8000000e+00, 5.5000000e+00, 5.5000000e+00,
#          1.7241120e+09, 1.5864240e+06],
#         [5.6000000e+00, 5.6000000e+00, 5.5000000e+00, 5.5000000e+00,
#          1.7241984e+09, 1.3858600e+05],
#         [5.5000000e+00, 5.6000000e+00, 5.4000000e+00, 5.5000000e+00,
#          1.7242848e+09, 1.2544530e+06],
#         [5.6000000e+00, 5.6000000e+00, 5.4000000e+00, 5.5000000e+00,
#          1.7243712e+09, 1.0444900e+05],
#         [5.4000000e+00, 5.5000000e+00, 5.2000000e+00, 5.3000000e+00,
#          1.7246304e+09, 1.7849570e+06],
#         [5.3000000e+00, 5.3000000e+00, 5.1000000e+00, 5.2000000e+00,
#          1.7247168e+09, 1.3530540e+06],
#         [5.2000000e+00, 5.3000000e+00, 5.0000000e+00, 5.0000000e+00,
#          1.7248032e+09, 2.0014850e+06],
#         [5.2000000e+00, 5.2000000e+00, 5.0000000e+00, 5.0000000e+00,
#          1.7248896e+09, 7.4122500e+05],
#         [5.0000000e+00, 5.1000000e+00, 5.0000000e+00, 5.0000000e+00,
#          1.7249760e+09, 2.1885760e+06],
#         [5.0000000e+00, 5.1000000e+00, 4.8000000e+00, 4.9000000e+00,
#          1.7252352e+09, 3.7374120e+06]]),
#  datetime.datetime(2024, 5, 6, 0, 0),
#  0)

# %%
np.unique(np.array([h[3] for h in dataset]), return_counts=1)
# Out:
# (array([0, 1]), array([655, 700]))

# %%
up = [d for d in dataset if d[3] == 1]
down = [d for d in dataset if d[3] == 0]

# %%
for idx, i in enumerate(down[7:8]):
    matrix1 = np.moveaxis(i[0], 1, 0)
    matrix2 = np.moveaxis(i[1], 1, 0)
    fig, axes = plt.subplots(1, 1)
    candle(np.concatenate((matrix1, matrix2), axis=1), ax=axes, t0=i[2])
    fig.savefig("/mnt/c/Users/malis/4th year/research/thesis/images/down.png")

# %%
# np.array_equal(temp, matrix1)

# %%
# t_dt = pd.DataFrame(records)
# t_dt.to_excel("/mnt/c/Users/malis/Desktop/Linux/reversal_data.xlsx")

# %%
# t_dt["Count"].sum()

# %%
def get_point_and_cluster(stock_name):

    DATABASE_URL = "postgresql://overcat:overmind@localhost:5432/stocks"
    
    query = """
    SELECT point, cluster
    FROM data.reversals
    WHERE stock = %s;
    """
    results = []
    try:
        with psycopg2.connect(DATABASE_URL) as conn:
            with conn.cursor() as cur:
                cur.execute(query, (stock_name,))
                rows = cur.fetchall()
                results = [(row[0], row[1]) for row in rows]
    except Exception as e:
        print(f"Error fetching data: {e}")
    return results

# %%
# Example Usage
stock = "jkh"
points = get_point_and_cluster(stock.upper())
cluster0 = [i[0] for i in points if i[1] == 0]
cluster1 = [i[0] for i in points if i[1] == 1]
cluster2 = [i[0] for i in points if i[1] == 2]

rows = dbloader(stock.upper())
mat = to_mat(rows)
cp = mat[3]
t = mat[4]
t = pd.to_datetime(t, unit='s').sort_values()

cluster0_index = [np.where(t == i)[0][0] for i in cluster0]
cluster1_index = [np.where(t == i)[0][0] for i in cluster1]
cluster2_index = [np.where(t == i)[0][0] for i in cluster2]

plt.figure(figsize=(15, 7))
plt.plot(cp, alpha=0.5)
plt.plot(cluster0_index, cp[cluster0_index], "x", )
plt.plot(cluster1_index, cp[cluster1_index], "o")
plt.plot(cluster2_index, cp[cluster2_index], "^")
# plt.title(f"{i} peaks and valleys")
plt.xticks([])
plt.yticks([])
# Out:
# ([], [])

# %%
DATABASE_URL = "postgresql://overcat:overmind@localhost:5432/stocks"

query = """
SELECT cluster, trend
FROM data.reversals;
"""
results = []
try:
    with psycopg2.connect(DATABASE_URL) as conn:
        with conn.cursor() as cur:
            cur.execute(query)
            rows = cur.fetchall()
            results = [(row[0], row[1]) for row in rows]
except Exception as e:
    print(f"Error fetching data: {e}")

# %%
tmp = np.array(results)
np.unique(tmp[tmp[:, 0] == 1, 1], return_counts=1)
# Out:
# (array([0, 1]), array([246, 154]))

# %%
np.unique(tmp[tmp[:, 0] == 0, 1], return_counts=1)
# Out:
# (array([0, 1]), array([409, 546]))
