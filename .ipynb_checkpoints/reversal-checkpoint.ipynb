# %%
import pickle
import psycopg2
import datetime
import time
import numpy as np
import pandas as pd
from scipy.signal import find_peaks
import matplotlib.pyplot as plt
import seaborn as sns
import mplfinance as mpf
import hashlib
import math

# %%
def dbloader(stock, year=2000):
    DATABASE_URL = "postgresql://overcat:overmind@localhost:5432/stocks"
    
    conn = psycopg2.connect(DATABASE_URL)
    cur = conn.cursor()
    
    date_time = datetime.datetime(year, 1, 1, 5, 30)
    limit_stamp = int(time.mktime(date_time.timetuple()))
    
    cur.execute(f"SELECT * FROM {stock} WHERE timestamp > {limit_stamp} ")
    
    rows = cur.fetchall()

    return rows

def to_mat(rows):
    rows = sorted(rows, key=lambda row: row[0])
    window = [row[0: 6] for row in rows]
    window = np.array(window)
    Time = window[:, 0]
    Open = window[:, 1]
    High = window[:, 3]
    Low = window[:, 4]
    Close = window[:, 2]
    Volume = window[:, 5]
    mat = np.vstack((Open, High, Low, Close, Time, Volume))
    return mat

# %%
import json

with open('turnover.json', 'r') as f:
    tickers = json.load(f)

stock_info = pd.read_csv("stock_info.csv")

# %%
def candle(mat, t0, ax):
    data = {
        'Open': mat[0],
        'High': mat[1],
        'Low': mat[2],
        'Close': mat[3]
    }

    # Create DataFrame for first dataset
    df = pd.DataFrame(data)
    # df.index = pd.to_datetime(mat[4], unit='s')
    # df.index = pd.date_range(start="2023-01-01", periods=len(df), freq="D")
    df.index = pd.to_datetime(mat[4], unit='s')
    df["mco"] = None
    df.loc[df.index < t0, "mco"] = "black"
    mco = df["mco"].values
    # mpf.plot(df, type='candle', style='yahoo', ax=ax, marketcolor_overrides=mco)

    mpf.plot(df, type='candle', style='yahoo', marketcolor_overrides=mco, ax=ax)

# %%
tickers[:1]
# Out:
# ['UBC']

# %%
def to_json(matrix):
            mat_list = matrix.tolist()
            mat_dict = {"Open": mat_list[0], "High": mat_list[1], "Low": mat_list[2], "Close": mat_list[3], "Time": mat_list[4], "Volume": mat_list[5]}
            return json.dumps(mat_dict)

# %%
# records = []

for i in tickers:
    record = {}
    rows = dbloader(i)
    mat = to_mat(rows)
    cp = mat[3]
    t = mat[4]
    t = pd.to_datetime(t, unit='s').sort_values()

    prom = np.mean([np.std(i) for i in np.array_split(cp, 10)])
    peaks, _ = find_peaks(cp, prominence=prom)
    valleys, _ = find_peaks(-cp, prominence=prom)


    t_pairs = []
    for k in range(len(valleys)):
        valley = valleys[k]
    
        for j in range(len(peaks)):
            peak = peaks[j]
            if valley < peak:
                t_pairs.append((t[valley], t[peak]))
                break

    alt_pairs = []
    for k in range(len(peaks)):
        peak = peaks[k]
    
        for j in range(len(valleys)):
            valley = valleys[j]
            if valley > peak:
                alt_pairs.append((t[peak], t[valley]))
                break
                
    # record["Stock"] = i
    # record["Company"] = stock_info[stock_info["security"] == f"{i}.N0000"]["company_name"].values[0]
    # record["Count"] = len(t_pairs)
    # records.append(record)
                
    # fig, axes = plt.subplots(int(np.ceil(len(alt_pairs) / 3)), 3, figsize=(14, 20))
    # axes = axes.flatten()

    # for idx, date in enumerate(t_pairs):
        
    #     temp_neutral = t_pairs[idx]
    #     index0_neutral = np.where(t == temp_neutral[0])[0][0]
    #     index1_neutral = np.where(t == temp_neutral[1])[0][0]
    #     dif = index1_neutral - index0_neutral

    #     if  dif > 42:
    #         num1 = math.floor(dif / 3) + index0_neutral
    #         matrix1_neutral = mat[:, num1-14:num1]
    #         matrix2_neutral = mat[:, num1:num1+28]
    #         mm_neutral = mat[:, num1-14:num1+28]
    #         # print(matrix1_neutral.shape, matrix2_neutral.shape, mm_neutral.shape)
            
    #         # fig, axes = plt.subplots(1, 1)
    #         # candle(mm_neutral, axes, t[num1])
    #         # axes.set_xticks([])  # Remove x-axis ticks
    #         # axes.set_yticks([])  # Remove y-axis ticks
    #         # axes.set_ylabel("")
    #         # plt.tight_layout()

    #         try:
    #             insert_db(matrix1_neutral, matrix2_neutral, i, t[num1], 0)
    #         except psycopg2.Error as e:
    #             print(f"Error occurred: {e}")

    for idx, date in enumerate(t_pairs):
        # print("##############################")
        
        temp = t_pairs[idx]
        # t2 = (t >= temp[0]) & (t <= temp[1])

        index0 = np.where(t == temp[0])[0][0]
        index1 = np.where(t == temp[1])[0][0]

        if index0 >= 13:
            matrix1 = mat[:, index0-15:index0+1]
            matrix2 = mat[:, index0+1:index1+1]
            mm = mat[:, index0-15:index1+1]
            
            # candle(mm, axes[idx], temp[0])
            # axes[idx].set_xticks([])  # Remove x-axis ticks
            # axes[idx].set_yticks([])  # Remove y-axis ticks
            # axes[idx].set_ylabel("")
            # plt.tight_layout()

            try:
                insert_db(matrix1, matrix2, i, temp[0], 1)
            except psycopg2.Error as e:
                print(f"Error occurred: {e}")
        else:
            print(index0)
            pass
        
    for idx, date in enumerate(alt_pairs):
        temp_alt = alt_pairs[idx]
        # t2 = (t >= temp[0]) & (t <= temp[1])

        index0_alt = np.where(t == temp_alt[0])[0][0]
        index1_alt = np.where(t == temp_alt[1])[0][0]

        if index0_alt >= 13:
            matrix1_alt = mat[:, index0_alt-15:index0_alt+1]
            matrix2_alt = mat[:, index0_alt+1:index1_alt+1]
            mm_alt = mat[:, index0_alt-15:index1_alt+1]
            
            # candle(mm_alt, axes[idx], temp_alt[0])
            # axes[idx].set_xticks([])  # Remove x-axis ticks
            # axes[idx].set_yticks([])  # Remove y-axis ticks
            # axes[idx].set_ylabel("")
            # plt.tight_layout()

            try:
                insert_db(matrix1_alt, matrix2_alt, i, temp_alt[0], 0)
            except psycopg2.Error as e:
                print(f"Error occurred: {e}")
            
        else:
            print(index0_alt)
            pass
        
        

        # candle(mm, axes[idx], temp[0])
        # axes[idx].plot(t[t2], cp[t2])
        # axes[idx].plot(t[t1], cp[t1], c="r")

        # plt.savefig("/mnt/c/Users/malis/Desktop/Linux/trend_reversal.png", dpi=300, bbox_inches='tight')

        ############
        # dif = temp[1] - temp[0]
        # dif = datetime.timedelta(days=14)
        ############
        
        # origin = temp[0] - dif
        # t1 = (t >= origin) & (t < temp[0])
        # m1 = mat[:, t1]
        # m2 = mat[:, t2]

        # tt = (t >= origin) & (t <= temp[1])
        # mm = mat[:, tt]
        
        # matrix1 = mm[:, mm[4] < temp[0].timestamp()]
        # matrix2 = mm[:, mm[4] > temp[0].timestamp()]

    #########
                
    # plt.figure(figsize=(10, len(t_pairs)))
    # plt.figure(figsize=(10, 7))
    # plt.plot(cp, alpha=0.5)
    # plt.plot(peaks, cp[peaks], "x", )
    # plt.plot(valleys, cp[valleys], "o")
    # plt.title(f"{i} peaks and valleys")
    # plt.xticks([])
    # plt.yticks([])
    # plt.savefig("/mnt/c/Users/malis/Desktop/Linux/tjl_p_v.png", dpi=300, bbox_inches='tight')
# Out:
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(212712146515230744) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(216213512016580170) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(564683614972265048) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(271391487708597970) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(289517671430843338) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(325070402518767012) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(294588632445566405) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(613159462426686268) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(613877335553377676) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(686181234186160684) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(610169717111411311) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(115628515665750105) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(834491626484708038) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(47961345533355002) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(554289255366322662) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(877293154677884174) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(395952924943051605) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(918415223336715460) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(352017086252075332) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(448245749011293897) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(988650029357880808) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(817886466405904236) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(711000278554933183) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(678923824570081582) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(884457697557257801) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(882255391737620205) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(54014556914444923) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(499431341744641217) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(978348119097620947) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(701675520183542586) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(262269879126921447) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(197239573741525695) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(200288174421780028) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(436320655638571810) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(312346952820264010) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(209217920914371260) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(931162444275083210) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(164423104863196761) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(892865459163924778) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(804408967962844033) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(527160273148600193) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(646984173011506787) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(276647233198144198) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(95841131394684375) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(99677953706275747) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(479911686516722269) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(914224196127985783) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(715911953529232338) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(457594751023030552) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(5793915801069904) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(46692106432106581) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(777384676694394017) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(301046700695525010) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(508498047066955427) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(295820326504774377) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(428354509270422245) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(888917072940724913) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(594468276271583599) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(746157502350634676) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(985306344036586158) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(835885364907183043) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(395680073801720829) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(122449305291886793) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(830646014288748822) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(53278549726742205) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(158667943903136045) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(8807143128917766) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(260194091637059576) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(533317681638271557) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(10613723316678400) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(929841560079257375) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(595236905061112858) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(696376127421531409) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(708699637503031182) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(325615371610250075) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(847082417867583737) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(860661478638185103) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(916127436214344688) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(248695530811513190) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(411049264238725250) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(860775015456076661) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(108256978394298268) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(182109539504071383) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(631133279172476520) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(329711390650067435) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(979650923468199862) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(214582810619635913) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(84615207444388926) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(439695822883529723) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(736014682600922736) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(718496767647941924) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(35995915867864545) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(923239508944275889) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(523074008961445444) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(734495147887562200) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(955219309829972469) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(321127570289231406) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(329315917223653632) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(765425814458515806) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(604210625561252563) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(574006578132468482) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(723707841153791096) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(845842748197930962) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(481549196119180461) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(935028859221101148) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(244082459109455231) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(888254336244984740) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(83882097499707085) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(398459406425641771) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(706044593706321041) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(123554125932441759) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(305282317739705225) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(171495235441033609) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(391290720389957992) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(322863223416075724) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(4647690390859570) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(981512664995856406) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(810136589149882372) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(260541494874082169) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(901042932550404710) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(707609934073598959) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(61772655640696629) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(63136616800585998) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(334350722606679547) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(999262589318052364) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(357899984961475988) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(710376938478804998) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(396639744371872637) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(961704948440145679) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(411093052528900611) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(438695839130489713) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(232836891191216277) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(396029778659877789) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(195210875774311278) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(206059431349166223) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(363924516744542329) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(504811178844429187) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(758720804498607857) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(104785833910933227) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(310602209930305415) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(484568546877677787) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(811807382553055715) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(541030904152693940) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(528001153474111680) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(247369878639959458) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(102552472081309739) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(522860824920416185) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(639749940104000153) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(96273501031345064) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(402849057839926432) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(207316876871534594) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(273098441758287319) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(894367047543958740) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(255639442747736293) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(323827795320624547) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(881644639889512036) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(30073238906311275) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(189943733501559349) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(994273464189067246) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(888677205509581701) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(208306683712784910) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(595211473600348516) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(151200425277352823) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(663085528377271651) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(977001340560296857) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(396130842234438594) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(750518858333587524) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(303889556475140327) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(847663201591293339) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(292650229583038382) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(388887490932120587) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(984901762799087217) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(925301602354721059) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(561214663324441750) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(346178135796553144) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(925885493946524483) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(861134611730548628) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(445654879868523817) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(319275070460999118) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(99274360062778329) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(937196645609580218) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(640211376950699042) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(74143286402219854) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(824900311253014531) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(531228342583993302) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(400115554869749032) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(661205241788563198) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(960416607788776883) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(516983846780828849) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(231808300709843719) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(415029507457288831) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(685457905156037737) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(206166912053195327) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(921714530565481091) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(735481858630193942) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(488845053597348675) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(577597460923866861) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(521038755592465708) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(922410195314142474) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(67106411555547280) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(906135314014178591) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(573454109290447699) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(722659536714467427) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(454617930808924973) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(438846370707912561) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(620099474336127984) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(770932656021282423) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(394283424140002931) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(480484838943558787) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(438440986277516452) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(695386247550677841) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(683705158620828144) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(391383323163274859) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(766064540845708262) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(852797375877853543) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(127906690804508344) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(384171933122956007) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(654233695707132716) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(879026773303965852) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(350016624292579500) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(867832815196521784) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(491625917121185366) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(23332242700088036) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(374865686885534175) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(53715063268637117) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(576418556095874280) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(344499733178657350) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(316967759467569780) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(37440691013692813) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(511269384299524570) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(999379960664273264) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(900303995354304790) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(594062680413247132) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(713660535779824386) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(996958017275524516) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(642137259317709735) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(396052099621110965) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(356424791421755276) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(672035301890431509) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(988348513275292430) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(579424308828309842) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(831074885471715584) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(957358114704440661) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(426992744186396737) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(261009371992751276) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(970628829718061296) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(382995642076750906) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(264740363316033163) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(262195457966389776) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(129006143043318213) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(688929421355299619) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(985927324853215644) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(569514247070394328) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(587616507388794875) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(411692464536133580) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(694488980036044835) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(276955886237889939) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(282434954005076269) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(609297267084907091) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(294260496253847587) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(471895980484221807) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(929356753226940031) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(260445259822224763) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(933375667528436192) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(302180205573204082) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(375131916597505208) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(406277077705881872) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(417848971166032721) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(880788904570970388) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(642385967050078473) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(376260944334216831) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(641994934243155597) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(70039712680496938) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(156547368547380322) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(568280728883780251) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(18137483429642886) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(952294795286456529) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(947747221326006081) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(807402209995990982) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(358285633137535230) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(814834412776995626) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(91406018101694826) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(790020965958277840) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(507766036231610377) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(357392835536063383) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(267147984292632182) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(15262321492237618) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(348645314105152639) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(381710463922913092) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(85236495158753618) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(248833975176067728) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(828287675003443162) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(423349896242139450) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(668760673488696675) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(336664021468459120) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(677468141040388645) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(387860339490729408) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(598835144382829582) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(745702785812332234) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(663234775982415399) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(888939427573237982) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(569745035066405416) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(757402110325399755) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(829184436581210204) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(14359909372677698) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(746291898454845995) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(161378383582096346) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(160993649028810951) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(998430911863813117) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(754298856425205615) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(131519519323217700) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(72620438470216225) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(610725307292749243) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(682739291006331531) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(844257718244736891) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(841581532769891911) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(821334063099317139) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(483792886128219161) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(78851432217837720) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(678154697573583668) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(734645487551300579) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(427009704870271572) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(711451017054752218) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(56105059129615889) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(538956733740232882) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(773837944728339225) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(111246877140012443) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(713487496931492331) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(472636806244107880) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(130131806255216313) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(170400259633543224) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(410130294091763540) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(69818307197929706) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(219213887467755877) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(870509242166569095) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(346100967165087014) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(61765522414060094) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(489205756653311072) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(139135619883310141) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(955635008741842363) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(386671684567269356) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(532638415615250314) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(713607655929252118) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(750515890417268422) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(510478398909120486) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(208531374358074479) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(424727013915418870) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(208204140723086064) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(823938608855652218) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(215163086070306636) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(830563467268876474) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(828067488223408394) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(535542817964314319) already exists.
#
# ...
# DETAIL:  Key (id)=(528175375783246316) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(484753077515649309) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(989538381572478593) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(848339323600423731) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(611400630405636502) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(309079662351008869) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(415481636614213354) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(312379728128105101) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(726488148822399194) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(412722832463447033) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(436474089082974063) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(678901801680176412) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(231894078159817753) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(924379245461592783) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(144208765187156151) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(66932435360161031) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(929147828304900743) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(585781808389107274) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(255620789107915915) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(781775875842850816) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(717903926327092570) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(831875693350489382) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(695904256826426687) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(372691644640565138) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(294846284005277283) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(267192005288572508) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(239616306759754738) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(525263892562064624) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(142019024582456937) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(210748167127538829) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(950928724272809118) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(526674915775046897) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(95610571889427260) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(929520324051047088) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(852289998528145008) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(158220944674212645) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(672013905200867423) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(88311416552761325) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(126992049376612090) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(261011779990607282) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(16902060254902788) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(693590380641500863) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(804130108789730624) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(362621099766776413) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(29348505881939567) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(963374471627819401) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(527535568013283557) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(294527249320472788) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(740153450495072086) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(232524388073673769) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(966897142841552155) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(280163380155697179) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(200149820973353826) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(213999639040016759) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(548928165728282247) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(792614880131734091) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(595643639483181715) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(225166701085708899) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(494392852309271221) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(50586344258566259) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(128249523010182824) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(403560141199925489) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(54069059580268952) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(59309440954870639) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(770798973298952138) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(925626113079004730) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(470725692248007389) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(497550979490429589) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(176096822405279656) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(664084364344544222) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(916968075821206182) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(429596402508677220) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(506458225265123955) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(563120464574722347) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(742286322541844259) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(298550900748514293) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(332229210511824267) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(891650076504983979) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(887638936693367193) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(681011489251766096) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(540122745303686781) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(682056173796312193) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(241092536015795345) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(979727354490797421) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(346046674890322604) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(950562263766364732) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(199639995289158009) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(623420781885360343) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(897741154244245041) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(605549044755250716) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(754200950212580917) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(628605106556415822) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(728273389886883318) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(544517480611402364) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(717403761329359186) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(692467402868638344) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(693421917846640219) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(109585065595620659) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(312709845737151367) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(724638512767441009) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(102830095277888089) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(884714002720790230) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(408608830534907718) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(798850037475497125) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(435681934443979489) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(680081768412452103) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(568351595380099303) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(83793873532320966) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(582076359481672298) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(610354784037900806) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(942731944517455058) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(25338785109059658) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(432852760564785100) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(650702083566023239) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(295023439578749948) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(17928664376392444) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(802061533100795401) already exists.
#
# Error occurred: duplicate key value violates unique constraint "reversals_pkey"
# DETAIL:  Key (id)=(249206694701435273) already exists.

# %%
# matrix1 = mm[:, mm[4] < temp[0].timestamp()]
# matrix2 = mm[:, mm[4] > temp[0].timestamp()]
# matrix1.shape, matrix2.shape

# def to_json(matrix):
#     mat_list = matrix.tolist()
#     mat_dict = {"Open": mat_list[0], "High": mat_list[1], "Low": mat_list[2], "Close": mat_list[3], "Time": mat_list[4]}
#     return json.dumps(mat_dict)

# %%
DATABASE_URL = "postgresql://overcat:overmind@localhost:5432/stocks"
conn = psycopg2.connect(DATABASE_URL)

query = """
DO $$
BEGIN
    -- Create schema if it doesn't exist
    IF NOT EXISTS (SELECT 1 FROM information_schema.schemata WHERE schema_name = 'data') THEN
        EXECUTE 'CREATE SCHEMA data';
    END IF;

    -- Create table if it doesn't exist
    IF NOT EXISTS (
        SELECT 1 FROM information_schema.tables 
        WHERE table_schema = 'data' AND table_name = 'reversals'
    ) THEN
        EXECUTE '
        CREATE TABLE data.reversals (
            id TEXT PRIMARY KEY, 
            matrix1 JSONB NOT NULL,
            matrix2 JSONB NOT NULL,
            stock TEXT NOT NULL,
            point TIMESTAMP NOT NULL,
            trend INTEGER
        )';
    END IF;
END $$;
"""
try:
    with conn.cursor() as cur:
        cur.execute(query)
        conn.commit()
        print("schema and table created successfully")
finally:
    conn.close()
# Out:
# schema and table created successfully

# %%
def generate_unique_number(stock_name, stock_date):
    # Combine stock name and date into a string
    combined_string = f"{stock_name}_{stock_date.strftime('%Y%m%d')}"
    
    # Hash the combined string using SHA-256
    hash_object = hashlib.sha256(combined_string.encode())
    hex_dig = hash_object.hexdigest()
    
    # Convert the hex digest into a number (you can also take a substring of the hash for a shorter number)
    unique_number = int(hex_dig, 16)  # Convert hex to an integer
    
    # Optionally, limit the size of the number (e.g., modulo a large number to prevent overflow)
    unique_number = unique_number % (10**18)  # Limiting it to an 18-digit number
    
    return unique_number

# %%
def insert_db(matrix1, matrix2, stock, point, trend):
    DATABASE_URL = "postgresql://overcat:overmind@localhost:5432/stocks"
    conn = psycopg2.connect(DATABASE_URL)
    
    query = """
    INSERT INTO data.reversals (id, matrix1, matrix2, stock, point, trend)
    VALUES (%s, %s, %s, %s, %s, %s)
    """
    try:
        with conn.cursor() as cur:
            cur.execute(query, [generate_unique_number(stock, point), to_json(matrix1), to_json(matrix2), stock, point.strftime('%Y-%m-%d'), trend])
            conn.commit()
            print("data inserted successfully")
    finally:
        conn.close()

# %%
def pgDataLoader():
    DATABASE_URL = "postgresql://overcat:overmind@localhost:5432/stocks"
    conn = psycopg2.connect(DATABASE_URL)
    
    query = """
    SELECT * from data.reversals;
    """
    
    dataset = []
    
    try:
        conn = psycopg2.connect(DATABASE_URL)
        with conn.cursor() as cur:
            cur.execute(query)
            results = cur.fetchall()  # Fetch all rows from the query result
            
            for row in results:
                matrix1 = np.array([
                    row[1]["Open"],
                    row[1]["High"],
                    row[1]["Low"],
                    row[1]["Close"],
                    row[1]["Time"],
                    row[1]["Volume"]
                ])
    
                matrix2 = np.array([
                    row[2]["Open"],
                    row[2]["High"],
                    row[2]["Low"],
                    row[2]["Close"],
                    row[2]["Time"],
                    row[2]["Volume"]
                ])
    
                # print(row[3], row[4])
                # fig, axes = plt.subplots(1, 1)
                # candle(np.concatenate((matrix1, matrix2), axis=1), ax=axes, t0=row[4])
    
                matrix1 = np.moveaxis(matrix1, 1, 0)
                matrix2 = np.moveaxis(matrix2, 1, 0)
    
                # fig, axes = plt.subplots(1, 1)
                # candle(np.moveaxis(np.concatenate((matrix1, matrix2)), 1, 0), ax=axes, t0=temp[0])
                dataset.append((matrix1, matrix2, row[4], row[5]))
    finally:
        conn.close()
        
    return dataset

# %%
dataset = pgDataLoader()

# %%
len(dataset)
# Out:
# 1355

# %%
dataset[0]
# Out:
# (array([[3.5000000e+01, 3.5100000e+01, 3.4200000e+01, 3.4400000e+01,
#          1.3030848e+09, 1.8010000e+05],
#         [3.4500000e+01, 3.4900000e+01, 3.3800000e+01, 3.4000000e+01,
#          1.3031712e+09, 3.3820000e+05],
#         [3.4000000e+01, 3.4100000e+01, 3.3700000e+01, 3.4000000e+01,
#          1.3032576e+09, 1.9420000e+05],
#         [4.0000000e+01, 4.0000000e+01, 3.3900000e+01, 3.4000000e+01,
#          1.3033440e+09, 5.9690000e+05],
#         [3.4400000e+01, 3.4400000e+01, 3.3000000e+01, 3.3100000e+01,
#          1.3036896e+09, 3.5210000e+05],
#         [3.3000000e+01, 3.3200000e+01, 3.2600000e+01, 3.2700000e+01,
#          1.3037760e+09, 2.8260000e+05],
#         [3.2600000e+01, 3.3000000e+01, 3.2500000e+01, 3.2800000e+01,
#          1.3038624e+09, 1.1690000e+05],
#         [3.3000000e+01, 3.4000000e+01, 3.2600000e+01, 3.2800000e+01,
#          1.3039488e+09, 5.0780000e+05],
#         [3.3000000e+01, 3.3000000e+01, 3.2400000e+01, 3.2500000e+01,
#          1.3040352e+09, 4.0000000e+05],
#         [3.6000000e+01, 3.6000000e+01, 3.1500000e+01, 3.1600000e+01,
#          1.3043808e+09, 3.9970000e+05],
#         [3.2000000e+01, 3.2000000e+01, 2.9900000e+01, 3.0000000e+01,
#          1.3044672e+09, 5.2580000e+05],
#         [3.0300000e+01, 3.0700000e+01, 3.0100000e+01, 3.0200000e+01,
#          1.3045536e+09, 3.9020000e+05],
#         [3.0500000e+01, 3.0500000e+01, 2.9900000e+01, 2.9900000e+01,
#          1.3046400e+09, 8.1570000e+05],
#         [3.0000000e+01, 3.0100000e+01, 2.8900000e+01, 2.9100000e+01,
#          1.3048992e+09, 4.1720000e+05],
#         [2.9800000e+01, 2.9800000e+01, 2.8000000e+01, 2.8300000e+01,
#          1.3049856e+09, 3.2360000e+05],
#         [2.8000000e+01, 2.8300000e+01, 2.6900000e+01, 2.7100000e+01,
#          1.3050720e+09, 1.1519000e+06]]),
#  array([[2.7200000e+01, 2.7500000e+01, 2.7200000e+01, 2.7300000e+01,
#          1.3051584e+09, 1.6090000e+05],
#         [2.7400000e+01, 2.9000000e+01, 2.7400000e+01, 2.8200000e+01,
#          1.3052448e+09, 7.1090000e+05],
#         [2.8300000e+01, 2.8600000e+01, 2.7800000e+01, 2.8200000e+01,
#          1.3055040e+09, 3.8240000e+05],
#         [2.8300000e+01, 2.9300000e+01, 2.7800000e+01, 2.9200000e+01,
#          1.3057632e+09, 9.6660000e+05],
#         [2.9400000e+01, 3.2600000e+01, 2.9400000e+01, 3.0800000e+01,
#          1.3058496e+09, 1.9550000e+06],
#         [3.0900000e+01, 3.1800000e+01, 3.0700000e+01, 3.1000000e+01,
#          1.3061088e+09, 4.9210000e+05]]),
#  datetime.datetime(2011, 5, 11, 0, 0),
#  1)

# %%
np.unique(np.array([h[3] for h in dataset]), return_counts=1)
# Out:
# (array([0, 1]), array([655, 700]))

# %%
up = [d for d in dataset if d[3] == 1]
down = [d for d in dataset if d[3] == 0]

# %%
for idx, i in enumerate(down[7:8]):
    matrix1 = np.moveaxis(i[0], 1, 0)
    matrix2 = np.moveaxis(i[1], 1, 0)
    fig, axes = plt.subplots(1, 1)
    candle(np.concatenate((matrix1, matrix2), axis=1), ax=axes, t0=i[2])
    fig.savefig("/mnt/c/Users/malis/4th year/research/thesis/images/down.png")

# %%
# np.array_equal(temp, matrix1)

# %%
# t_dt = pd.DataFrame(records)
# t_dt.to_excel("/mnt/c/Users/malis/Desktop/Linux/reversal_data.xlsx")

# %%
# t_dt["Count"].sum()

# %%
def get_point_and_cluster(stock_name):

    DATABASE_URL = "postgresql://overcat:overmind@localhost:5432/stocks"
    
    query = """
    SELECT point, cluster
    FROM data.reversals
    WHERE stock = %s;
    """
    results = []
    try:
        with psycopg2.connect(DATABASE_URL) as conn:
            with conn.cursor() as cur:
                cur.execute(query, (stock_name,))
                rows = cur.fetchall()
                results = [(row[0], row[1]) for row in rows]
    except Exception as e:
        print(f"Error fetching data: {e}")
    return results

# %%
# Example Usage
stock = "lofc"
points = get_point_and_cluster(stock.upper())
cluster0 = [i[0] for i in points if i[1] == 0]
cluster1 = [i[0] for i in points if i[1] == 1]

rows = dbloader(stock.upper())
mat = to_mat(rows)
cp = mat[3]
t = mat[4]
t = pd.to_datetime(t, unit='s').sort_values()

cluster0_index = [np.where(t == i)[0][0] for i in cluster0]
cluster1_index = [np.where(t == i)[0][0] for i in cluster1]

plt.figure(figsize=(15, 7))
plt.plot(cp, alpha=0.5)
plt.plot(cluster0_index, cp[cluster0_index], "x", )
plt.plot(cluster1_index, cp[cluster1_index], "o")
plt.title(f"{i} peaks and valleys")
plt.xticks([])
plt.yticks([])
# Out:
# ([], [])
